# %%
# importing helper libraries
import numpy as np
import pandas as pd
# import machine learning libraries
import tensorflow as tf
from tensorflow import keras
# Importing data preprocessing techniques
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt
# Out:
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:tensorflow:From C:\Users\prati\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# WARNING:tensorflow:From C:\Users\prati\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# # Data Reading, Downloaded from Yahoo Finance

# %%
data = pd.read_csv("../BTC-USD.csv")
data.head()
# Out:
#          Date         Open         High          Low        Close  \
# 0  2019-04-23  5399.365723  5633.802246  5389.408691  5572.362305
# 1  2019-04-24  5571.508301  5642.044434  5418.263184  5464.866699
# 2  2019-04-25  5466.524414  5542.238281  5181.338867  5210.515625
# 3  2019-04-26  5210.304688  5383.634277  5177.368652  5279.348145
# 4  2019-04-27  5279.471191  5310.750000  5233.635742  5268.291016
#
#      Adj Close        Volume
# 0  5572.362305  1.586731e+10
# 1  5464.866699  1.704803e+10
# 2  5210.515625  1.533028e+10
# 3  5279.348145  1.681211e+10
# 4  5268.291016  1.311127e+10

# %%
data.isna().astype("int").sum()
# Out:
# Date         0
# Open         1
# High         1
# Low          1
# Close        1
# Adj Close    1
# Volume       1
# dtype: int64

# %%
# we need to remove null or NaN value from our dataset
data.dropna(inplace = True)
data.isna().astype("int").sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
required_data = data[["High", "Low", "Close"]]
required_data.head()
# Out:
#           High          Low        Close
# 0  5633.802246  5389.408691  5572.362305
# 1  5642.044434  5418.263184  5464.866699
# 2  5542.238281  5181.338867  5210.515625
# 3  5383.634277  5177.368652  5279.348145
# 4  5310.750000  5233.635742  5268.291016

# %% [markdown]
# # Data Preprocessing

# %%
train_data_length = int(0.9 * len(required_data))

# %%
# Before we normalize the data, we need to split the data into train and test split, so that data snooping can be
# avoided

train_data = required_data.iloc[:train_data_length]
test_data = required_data.iloc[train_data_length:]

print(f"Training data : {train_data.shape}")
print(f"Testing data : {test_data.shape}")
# Out:
# Training data : (1645, 3)
# Testing data : (183, 3)

# %%
# Data Normalization
# This will scale the data between -1 and 1
normalizer = MinMaxScaler(feature_range = (-1, 1))
# Fit the normalizer on the train data only
normalizer.fit(train_data)


# converting the train data
train_data = normalizer.transform(train_data)
test_data  = normalizer.transform(test_data)

print(f"Training data : {train_data.shape}")
print(f"Testing data : {test_data.shape}")
# Out:
# Training data : (1645, 3)
# Testing data : (183, 3)

# %%
import pickle

with open("../models/preprocessor.prec", "wb") as f:
    pickle.dump(normalizer, f)

# %%
# checking the range of train data and test data
print(f"Maximum and minimum value of training data : {np.max(train_data), np.min(train_data)}")
print(f"Maximum and minimum value of testing  data : {np.max(test_data), np.min(test_data)}")
# Out:
# Maximum and minimum value of training data : (1.0, -0.9999999999999999)
# Maximum and minimum value of testing  data : (1.1762626476551192, -0.0885956646837236)

# %%
# this piece of code creates the data where features and targets are multivariate

def create_window_split_with_target_multivariate(data, window_size, horizon=1, stride=1):
    """
    Function to split a multivariate time series data into overlapping windows and generate target variables.
    
    Parameters:
        data (numpy.ndarray): The input multivariate time series data with shape (num_samples, num_features).
        window_size (int): Size of each window.
        horizon (int): Forecast horizon, i.e., number of future time steps to predict. Default is 1.
        stride (int): The stride or step size between consecutive windows. Default is 1.
    
    Returns:
        numpy.ndarray, numpy.ndarray: Arrays containing the split windows and corresponding target variables.
    """
    num_samples = len(data)
    num_features = data.shape[1]
    num_windows = (num_samples - window_size - horizon) // stride + 1
    windows = np.zeros((num_windows, window_size, num_features))
    targets = np.zeros((num_windows, num_features))
    
    for i in range(num_windows):
        start_index = i * stride
        end_index = start_index + window_size
        windows[i] = data[start_index:end_index]
        targets[i] = data[end_index + horizon - 1]  # Assuming the target is the value at the end of the forecast horizon
    
    return windows, targets


window_size = 15
horizon = 1
stride = 1

train_features, train_lables = create_window_split_with_target_multivariate(train_data, window_size, horizon, stride)
test_features, test_lables = create_window_split_with_target_multivariate(test_data, window_size, horizon, stride)


print(f"Training Data : {train_features.shape, train_lables.shape}")
print(f"Testing Data : {test_features.shape, test_lables.shape}")
# Out:
# Training Data : ((1630, 15, 3), (1630, 3))
# Testing Data : ((168, 15, 3), (168, 3))

# %% [markdown]
# # Model Training and Evaluation

# %%
from tensorflow.keras.layers import GRU

model = tf.keras.Sequential(
    [
        keras.layers.Input(shape = (15, 3)),
        keras.layers.Bidirectional(GRU(units = 64, activation = "gelu", return_sequences = True)),
        keras.layers.GroupNormalization(),
        keras.layers.Bidirectional(GRU(units = 64, activation = "gelu")),
        keras.layers.GroupNormalization(),
        keras.layers.Dense(units = 32, activation = "gelu"),
        keras.layers.Dense(units = 3, activation = "tanh")  
    ]
)
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\prati\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# WARNING:tensorflow:From C:\Users\prati\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirection  (None, 15, 128)           26496
#  al)
#
#  group_normalization (Group  (None, 15, 128)           256
#  Normalization)
#
#  bidirectional_1 (Bidirecti  (None, 128)               74496
#  onal)
#
#  group_normalization_1 (Gro  (None, 128)               256
#  upNormalization)
#
#  dense (Dense)               (None, 32)                4128
#
#  dense_1 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 105731 (413.01 KB)
# Trainable params: 105731 (413.01 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
callbacks = []

model_ckpts = tf.keras.callbacks.ModelCheckpoint("../models/bigru/", monitor = "val_loss", save_best_only = True)
early_stops = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", patience = 10)

callbacks.append(model_ckpts)
callbacks.append(early_stops)

# %%
model.compile(optimizer = keras.optimizers.Adam(learning_rate = 0.001), loss = "mse", metrics = ["mse", "mae"])

# %%
history = model.fit(train_features, train_lables, epochs = 50, validation_data = (test_features, test_lables), callbacks = callbacks)
# Out:
# Epoch 1/50
# 50/51 [============================>.] - ETA: 0s - loss: 0.0915 - mse: 0.0915 - mae: 0.1889INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 16s 196ms/step - loss: 0.0900 - mse: 0.0900 - mae: 0.1866 - val_loss: 0.0413 - val_mse: 0.0413 - val_mae: 0.1632
# Epoch 2/50
# 51/51 [==============================] - ETA: 0s - loss: 0.0058 - mse: 0.0058 - mae: 0.0558INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 188ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0558 - val_loss: 0.0194 - val_mse: 0.0194 - val_mae: 0.1065
# Epoch 3/50
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0454 - val_loss: 0.0278 - val_mse: 0.0278 - val_mae: 0.1256
# Epoch 4/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.0027 - mse: 0.0027 - mae: 0.0366 - val_loss: 0.0212 - val_mse: 0.0212 - val_mae: 0.1173
# Epoch 5/50
# 51/51 [==============================] - ETA: 0s - loss: 0.0025 - mse: 0.0025 - mae: 0.0347INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 175ms/step - loss: 0.0025 - mse: 0.0025 - mae: 0.0347 - val_loss: 0.0183 - val_mse: 0.0183 - val_mae: 0.1034
# Epoch 6/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0020 - mse: 0.0020 - mae: 0.0312INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 182ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0313 - val_loss: 0.0126 - val_mse: 0.0126 - val_mae: 0.0827
# Epoch 7/50
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0301 - val_loss: 0.0136 - val_mse: 0.0136 - val_mae: 0.0830
# Epoch 8/50
# 51/51 [==============================] - 1s 18ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0291 - val_loss: 0.0137 - val_mse: 0.0137 - val_mae: 0.0915
# Epoch 9/50
# 51/51 [==============================] - ETA: 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0284INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 185ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0284 - val_loss: 0.0102 - val_mse: 0.0102 - val_mae: 0.0776
# Epoch 10/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0281 - val_loss: 0.0104 - val_mse: 0.0104 - val_mae: 0.0721
# Epoch 11/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0018 - mse: 0.0018 - mae: 0.0285INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 177ms/step - loss: 0.0018 - mse: 0.0018 - mae: 0.0285 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0635
# Epoch 12/50
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0272 - val_loss: 0.0149 - val_mse: 0.0149 - val_mae: 0.0923
# Epoch 13/50
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0319 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0838
# Epoch 14/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0017 - mse: 0.0017 - mae: 0.0274INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 183ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0273 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0669
# Epoch 15/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0252 - val_loss: 0.0100 - val_mse: 0.0100 - val_mae: 0.0692
# Epoch 16/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0265INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0263 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0627
# Epoch 17/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0270 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0678
# Epoch 18/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0253INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 187ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0252 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0626
# Epoch 19/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0262INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0261 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0617
# Epoch 20/50
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0241 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0628
# Epoch 21/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0246 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0659
# Epoch 22/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0305 - val_loss: 0.0101 - val_mse: 0.0101 - val_mae: 0.0758
# Epoch 23/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0017 - mse: 0.0017 - mae: 0.0275 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0595
# Epoch 24/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0238 - val_loss: 0.0094 - val_mse: 0.0094 - val_mae: 0.0722
# Epoch 25/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0260 - val_loss: 0.0098 - val_mse: 0.0098 - val_mae: 0.0699
# Epoch 26/50
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0014 - mse: 0.0014 - mae: 0.0252 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0685
# Epoch 27/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0245 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0627
# Epoch 28/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0245 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0718
# Epoch 29/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0011 - mse: 0.0011 - mae: 0.0221INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 176ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0223 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0605
# Epoch 30/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0229 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0584
# Epoch 31/50
# 51/51 [==============================] - 1s 22ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0245 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0662
# Epoch 32/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0235 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0619
# Epoch 33/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0012 - mse: 0.0012 - mae: 0.0236INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 10s 191ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0236 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0587
# Epoch 34/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0245 - val_loss: 0.0090 - val_mse: 0.0090 - val_mae: 0.0696
# Epoch 35/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0015 - mse: 0.0015 - mae: 0.0250 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0654
# Epoch 36/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0222 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0647
# Epoch 37/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0016 - mse: 0.0016 - mae: 0.0254 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0611
# Epoch 38/50
# 49/51 [===========================>..] - ETA: 0s - loss: 0.0014 - mse: 0.0014 - mae: 0.0247INFO:tensorflow:Assets written to: ../models/bigru\assets
# INFO:tensorflow:Assets written to: ../models/bigru\assets
# 51/51 [==============================] - 9s 174ms/step - loss: 0.0013 - mse: 0.0013 - mae: 0.0245 - val_loss: 0.0059 - val_mse: 0.0059 - val_mae: 0.0555
# Epoch 39/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0229 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0633
# Epoch 40/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0225 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0592
# Epoch 41/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0218 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0609
# Epoch 42/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0012 - mse: 0.0012 - mae: 0.0230 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0584
# Epoch 43/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0232 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0579
# Epoch 44/50
# 51/51 [==============================] - 1s 21ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0211 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0627
# Epoch 45/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0222 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0647
# Epoch 46/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0216 - val_loss: 0.0095 - val_mse: 0.0095 - val_mae: 0.0766
# Epoch 47/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0010 - mse: 0.0010 - mae: 0.0205 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0576
# Epoch 48/50
# 51/51 [==============================] - 1s 20ms/step - loss: 0.0011 - mse: 0.0011 - mae: 0.0224 - val_loss: 0.0061 - val_mse: 0.0061 - val_mae: 0.0562

# %%
train_loss = history.history["loss"]
valid_loss = history.history["val_loss"]

train_mae = history.history["mae"]
valid_mae = history.history["val_mae"]

plt.title("Model History")

plt.plot(range(len(train_loss)), train_loss, label = "train loss")
plt.plot(range(len(valid_loss)), valid_loss, label = "valid loss")

plt.plot(range(len(train_mae)), train_mae, label = "train mae")
plt.plot(range(len(valid_mae)), valid_mae, label = "valid mae")
plt.xlabel("Epoch")
plt.ylabel("Loss value")

plt.legend()
plt.show()

# %%
# Out:
# 6/6 [==============================] - 0s 8ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0562
# [0.006092469673603773, 0.006092469673603773, 0.0561693012714386]

# %%
model.load_weights("../models/bigru/")

test_predicts = model.predict(test_features)
# Out:
# 6/6 [==============================] - 0s 8ms/step

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].plot(test_lables[:, 0], label = "True High Value")
axes[0].plot(test_predicts[:, 0], label = "Predicted High Value")
axes[0].set_title('Plot 1')
axes[0].set_xlabel('Future Dates')
axes[0].set_ylabel('Predicted values')
axes[0].legend()

axes[1].plot(test_lables[:, 1], label = "True Low Value")
axes[1].plot(test_predicts[:, 1], label = "Predicted Low Value")
axes[1].set_title('Plot 1')
axes[1].set_xlabel('Future Dates')
axes[1].set_ylabel('Predicted values')
axes[1].legend()

axes[2].plot(test_lables[:, 2], label = "True Close Value")
axes[2].plot(test_predicts[:, 2], label = "Predicted Close Value")
axes[2].set_title('Plot 1')
axes[2].set_xlabel('Future Dates')
axes[2].set_ylabel('Predicted values')
axes[2].legend()
plt.show()

# %%
# Predicting future value based on only 1 initial windows

predictions = []
initial_data = test_features[0].reshape(1, 15, 3)

for i in range(len(test_features)):
    prediction = model.predict(initial_data)
    prediction = np.expand_dims(prediction, axis = 0)
    initial_data = np.concatenate((initial_data[:, 1:], prediction), axis = 1)
    
    prediction = np.squeeze(np.squeeze(prediction))
    predictions.append(prediction.tolist())
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step

# %%
predictions = np.asarray(predictions)

# %%
initial_data
# Out:
# array([[[-0.05985468, -0.07591351, -0.07563676],
#         [-0.06038008, -0.04931065, -0.0564249 ],
#         [-0.06985875, -0.04760162, -0.06748541],
#         [-0.08859566, -0.05869555, -0.07537241],
#         [-0.08351745, -0.04398925, -0.06962849],
#         [-0.07268326, -0.04165246, -0.05528553],
#         [-0.06951144, -0.03640458, -0.05643951],
#         [-0.07343966, -0.03729303, -0.05115425],
#         [-0.04796108, -0.03448668, -0.02656891],
#         [-0.03561323, -0.02707174, -0.04251278],
#         [-0.06640681, -0.03568298, -0.04909205],
#         [-0.05652766, -0.02016313, -0.03791335],
#         [-0.05387139, -0.0208841 , -0.03896261],
#         [-0.05558259, -0.01538845, -0.03934552],
#         [-0.03647732, -0.02243932, -0.02636734]]])

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

axes[0].plot(test_lables[:, 0], label = "True High Value")
axes[0].plot(predictions[:, 0], label = "Predicted High Value")
axes[0].set_title('Plot 1')
axes[0].set_xlabel('Future Dates')
axes[0].set_ylabel('Predicted values')
axes[0].legend()

axes[1].plot(test_lables[:, 1], label = "True Low Value")
axes[1].plot(predictions[:, 1], label = "Predicted Low Value")
axes[1].set_title('Plot 1')
axes[1].set_xlabel('Future Dates')
axes[1].set_ylabel('Predicted values')
axes[1].legend()

axes[2].plot(test_lables[:, 2], label = "True Close Value")
axes[2].plot(predictions[:, 2], label = "Predicted Close Value")
axes[2].set_title('Plot 1')
axes[2].set_xlabel('Future Dates')
axes[2].set_ylabel('Predicted values')
axes[2].legend()
plt.show()

# %%
import numpy as np

def predict_future_values(model, initial_data, num_predictions):
    predictions = []
    
    # Reshape initial data if necessary
    initial_data = np.array(initial_data)
    if len(initial_data.shape) == 2:
        initial_data = np.expand_dims(initial_data, axis=0)

    for _ in range(num_predictions):
        # Predict next value based on initial data
        prediction = model.predict(initial_data)
        
        # Append the predicted value to initial data for next prediction
        initial_data = np.concatenate((initial_data[:, 1:], np.expand_dims(prediction, axis=1)), axis=1)
        
        # Append the prediction to the list of predictions
        predictions.append(np.squeeze(prediction).tolist())
    
    predictions = np.asarray(predictions)
    
    return predictions

# Example usage:
# Assuming 'model' and 'test_features' are already defined
initial_data = test_features[0].reshape(1, 15, 3)
num_predictions = len(test_features)  # Number of predictions to make
predictions = predict_future_values(model, initial_data, num_predictions)
# Out:
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step

# %%
plt.plot(predictions[:, 1])
plt.plot(test_lables[:num_predictions, 1])
